# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
DATA_PATH = '../../data/raw/'

# %% [markdown]
# # transactions.json

# %%
df_transactions = pd.read_json(DATA_PATH + 'transactions.json')
df_transactions
# Out:
#                  event                        account_id  \
# 0       offer received  78afa995795e4d85b5d9ceeca43f5fef
# 1       offer received  a03223e636434f42ac4c3df47e8bac43
# 2       offer received  e2127556f4f64592b11af22de27a7932
# 3       offer received  8ec6ce2a7e7949b1bf142def7d0e0586
# 4       offer received  68617ca6246f4fbc85e91a2a49552598
# ...                ...                               ...
# 306529     transaction  b3a1272bc9904337b331bf348c3e8c17
# 306530     transaction  68213b08d99a4ae1b0dcb72aebd9aa35
# 306531     transaction  a00058cf10334a308c68e7631c529907
# 306532     transaction  76ddbd6576844afe811f1a3c0fbb5bec
# 306533     transaction  c02b10e8752c4d8e9b73f918558531f7
#
#                                                     value  \
# 0       {'amount': None, 'offer id': '9b98b8c7a33c4b65...
# 1       {'amount': None, 'offer id': '0b1e1539f2cc45b7...
# 2       {'amount': None, 'offer id': '2906b810c7d44117...
# ...
